# %% [markdown]
# <a href="https://colab.research.google.com/github/etcex2969-spec/-AIFFEL_quest_eng/blob/main/app_v4_5_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# !{sys.executable} -m pip install streamlit

import streamlit as st
import requests
import time

# 1. 페이지 기본 인프라 설정
st.set_page_config(page_title="Trading Orchestrator v4.5", layout="wide")

# 2. 백엔드 기지국 주소 매핑
BACKEND_URL = "http://localhost:8000"

# 3. 세션 상태 저장소 초기화 (Rerun 시 데이터 유지 목적)
if "audit_history" not in st.session_state:
    st.session_state.audit_history = []
if "is_frozen" not in st.session_state:
    st.session_state.is_frozen = False

st.title("🏆 Trading Insight Orchestrator v4.5")
st.subheader("인간 개입형(Human-in-the-Loop) 반자동 제어 대시보드")

# 좌우 화면 분할 레이아웃 배치 (UX 시각화 최적화)
col_left, col_right = st.columns([2, 1])

with col_left:
    st.markdown("### 📊 실시간 분석 리포트 및 시장 뷰판")

    # 백엔드 서버 헬스체크 및 실시간 데이터 징발 시도
    try:
        response = requests.get(f"{BACKEND_URL}/health", timeout=2)
        if response.status_code == 200:
            st.success("🟢 실시간 가상환경 백엔드 엔진 연동 중 (Port: 8000)")
        else:
            st.warning("🟡 백엔드 응답이 원활하지 않습니다.")
    except requests.exceptions.ConnectionError:
        st.error("🔴 [네트워크 비상상황] 8000번 백엔드 서버가 다운되었습니다. 즉시 확인하십시오.")
        st.session_state.is_frozen = True

    # HTML 뷰판 차트 렌더링 예시 (로컬 파일 임베딩)
    st.info("💡 트레이딩뷰 차트 시각화 및 에이전트 종합 보고서 대기 공간")
    # 향후 st.components.v1.html()을 사용해 trading_view_chart.html 탑재 예정

with col_right:
    st.markdown("### 🚨 실전 지시 상황판 및 비상 벨")

    # 비상벨 상태 시각화 제어
    if st.session_state.is_frozen:
        st.error("⛔ [FROZEN] 모든 자동 매매 파이프라인이 임시 동결되었습니다.")

    # 텍스트 지시 제어 인풋
    user_feedback = st.text_input(
        "사령관 지시 사항 입력 (예: Emergency, 매수 보류, 롱 진격)",
        placeholder="이곳에 지시 문맥을 입력하세요...",
        disabled=st.session_state.is_frozen
    )

    col_btn1, col_btn2 = st.columns(2)

    with col_btn1:
        if st.button("🚀 사격 개시 (승인)", use_container_width=True, disabled=st.session_state.is_frozen):
            if user_feedback:
                with st.spinner("가상환경 내 에이전트단 검증 통과 중..."):
                    try:
                        # FastAPI 백엔드로 Pydantic 규격에 맞춰 직렬화 데이터 전송 (Day 2, Day 4 융합)
                        payload = {"instruction": user_feedback}
                        res = requests.post(f"{BACKEND_URL}/orchestrate", json=payload, timeout=5)

                        if res.status_code == 200:
                            result_data = res.json()
                            st.session_state.audit_history.append(result_data)
                            st.success("✅ 주문 집행 최종 승인 완료")
                        elif res.status_code == 422:
                            st.error("❌ [422] 전송된 데이터 규격에 무결성 결함이 있습니다.")
                    except Exception as e:
                        st.error(f"통신 실패: {str(e)}")
            else:
                st.warning("지시 사항을 먼저 입력해 주십시오.")

    with col_btn2:
        # 물리 비상벨 버튼 (누르는 즉시 프론트단에서 상태 동결)
        if st.button("🛑 EMERGENCY (비상벨)", type="primary", use_container_width=True):
            st.session_state.is_frozen = True
            st.session_state.audit_history.append({"status": "EMERGENCY_SHUTDOWN", "time": time.time()})
            st.experimental_rerun()

    # 지시 및 통제 이력 모니터링
    st.markdown("#### 📜 최근 제어 감사 로그 (Audit History)")
    st.write(st.session_state.audit_history[-5:])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 85.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 70.2 MB/s eta 0:00:00
# ...
# 2026-06-12 03:48:16.142 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-12 03:48:16.144 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-12 03:48:16.146 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2026-06-12 03:48:16.148 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
